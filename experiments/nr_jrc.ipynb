# %% [markdown]
# ## NR-JRC
# In this notebook the experiments for NR-JRC for four different PDEs specified in the paper can be performed for finite difference order 2 and 8.<br>
# a)  $(x+t)^{-1}$,  $u_t=u_x=-u^2$ <br>
# b) $(x+t)^{-\frac{1}{2}}$,  $u_t=u_x=-\frac{1}{2}u^2$<br>
# c)  $\left(x + t\right) \arccos\left( \cosh(a t)^{-1} \right)$,  $u_t=u_x+\frac{u}{u_x}\cos(u)$  <br>
# d)  $\left(x + t\right)  \arcsin\left(\cosh(a t)^{-1}\right)$,
#   $u_t=u_x-\frac{u}{u_x}\sin(u)$   <br>

# %%
import numpy as np
from utils.test_data import *
from methods.error_bounds import *
from methods.jrc_analysis import *
# Seed the random number generators for reproducibility
np.random.seed(100)

# %% [markdown]
# ### Perform on all experiments

# %%
all_experiments_names= ['algebraic_nonunique_1','analytic_unique_1','analytic_unique_2','analytic_nonunique_1']
#Specifiy which experiments you want to run
experiment_names= ['algebraic_nonunique_1']

# %%
noise_levels = [0,1e-08,1e-05,0.01]
fd_orders=[2,8]
for experiment_name in experiment_names:
    for order in fd_orders:
        perform_experiment(noise_levels,order,experiment_name)
# Out:
# Performing experiment algebraic_nonunique_1 1/(t + x) with order 2, C2 = 1.00e-03
# Performing experiment algebraic_nonunique_1 1/(t + x) with order 8, C2 = 1.00e-03
